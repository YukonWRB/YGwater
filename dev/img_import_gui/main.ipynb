# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Load the GeoJSON file
gdf = gpd.read_file('C:/Users/esniede/Documents/combined-with-oceans.json')

# %%
gdf2 = gdf.drop(inplace=False).reset_index(drop=True).copy().drop(columns=['geometry']).to_dict()

# %%
# Simplify the geometries
gdf['geometry'] = gdf['geometry'].simplify(tolerance=0.1, preserve_topology=True)
# Export the simplified GeoDataFrame to a new GeoJSON file
gdf.to_file('simplified_combined_with_oceans.geojson', driver='GeoJSON')
# Plot the simplified GeoDataFrame
gdf.plot()

# Show the plot
plt.show()
